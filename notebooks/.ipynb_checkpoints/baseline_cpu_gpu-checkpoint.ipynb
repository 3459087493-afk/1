# %% [markdown]
# # Baseline: CPU/GPU performance comparison
#
# In this notebook, I will compare the inference speed of a transformer neural network on a cpu, gpu
#
# The model will additionally be compared with the optimized compiled model (PyTorch 2.0 feature)

# %% [markdown]
# Data:
# - from this paper: https://arxiv.org/pdf/2208.03938.pdf
# - https://github.com/NetManAIOps/KPI-Anomaly-Detection
# - https://github.com/rob-med/awesome-TS-anomaly-detection
# - used in this paper: https://www.mdpi.com/2073-8994/11/11/1350
#
# ```
# The dataset consists of KPI (key performace index) time series data from many real scenarios of Internet companies with ground truth label. KPIs fall into two broad categories: service KPIs and machine KPIs. Service KPIs are performance metrics that reflect the size and quality of a Web service, such as page response time, page views, and number of connection errors. Machine KPIs are performance indicators that reflect the health of the machine (server, router, switch), such as CPU utilization, memory utilization, disk IO, network card throughput, etc.
#
# Dataset Descriptions:
#
# In order to train the anomaly detection algorithm, the training KPI data provided by us is shown in table 1, including four columns: KPI ID, timestamp, the value of the KPI at that time, and whether the time is abnormal (label).
# ```

# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append("..")

# %%
from pathlib import Path

DATA_DIR = Path("../data/KPI-Anomaly-Detection/Preliminary_dataset")

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Dataset preparation

# %%
df = pd.read_csv(DATA_DIR / "train.csv", index_col="timestamp")
df = df.sort_index()
df["time"] = df.index - df.index[0]

# %%
df.head()
# Out:
#                value  label            KPI ID  time
# timestamp
# 1467302400  0.197575      0  07927a9a18fa19ae     0
# 1467302700  0.149877      0  07927a9a18fa19ae   300
# 1467303000  0.078893      0  07927a9a18fa19ae   600
# 1467303300  0.012004      0  07927a9a18fa19ae   900
# 1467303600 -0.022222      0  07927a9a18fa19ae  1200

# %%
pd.crosstab(df["KPI ID"], df["label"], normalize="index").sort_values(1, ascending=False).head()
# Out:
# label                    0         1
# KPI ID
# 02e99bd4f6cfb33f  0.917938  0.082062
# 1c35dbf57f55f5e4  0.925644  0.074356
# 18fbb1d5a5dc099d  0.939107  0.060893
# da403e4e3f87c9e0  0.940590  0.059410
# 88cf3a776ba00e7c  0.952534  0.047466

# %%
df = df[df["KPI ID"] == "02e99bd4f6cfb33f"].copy()
df["time"] = df.index - df.index[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128562 entries, 1493568000 to 1501475640
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   value   128562 non-null  float64
#  1   label   128562 non-null  int64
#  2   KPI ID  128562 non-null  object
#  3   time    128562 non-null  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 4.9+ MB

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(df.time)
plt.subplot(1, 2, 2)
plt.plot(df.time.diff())
plt.tight_layout();

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(df.value)
plt.subplot(1, 2, 2)
plt.scatter(df.index, df.label)
plt.tight_layout();

# %% [markdown]
# lets only take the values for timestamp > 1.49 * 1e9

# %%
df = df[df.index > 1.49 * 1e9].copy()
df["time"] = df.index - df.index[0]

# %%
plt.plot(df.value)

# %% [markdown]
# outliers are clearly visible...

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(df.value.diff())
plt.subplot(1, 2, 2)
plt.hist(df.value)
plt.yscale("log")
plt.tight_layout();

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(df.value.diff())
plt.subplot(1, 2, 2)
plt.hist(df.query("label==0").value, color="blue", alpha=0.5, label="0")
plt.hist(df.query("label==1").value, color="red", alpha=0.5, label="1")
plt.yscale("log")
plt.tight_layout();

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 8))
plt.sca(axs[0, 0])
plt.plot(df.value)
plt.sca(axs[0, 1])
plt.plot(df.value.diff())
plt.sca(axs[1, 0])
plt.hist(df.query("label==0").value, color="blue", alpha=0.5, label="0")
plt.hist(df.query("label==1").value, color="red", alpha=0.5, label="1")
plt.yscale("log")
plt.sca(axs[1, 1])
plt.scatter(df.index, df.label)
plt.tight_layout();

# %%
df.label.value_counts(normalize=True)
# Out:
# label
# 0    0.917938
# 1    0.082062
# Name: proportion, dtype: float64

# %% [markdown]
# timeseries looks quite stationary, anomalies seem to be nicely interleaved between normal observations with respect to time
#
# the dataset is unbalanced (only 8% of samples are anomalies)

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))

plt.plot(df.value, alpha=0.5)
t = df.query("label==1")
plt.scatter(t.index, t.value, color="red", alpha=0.8, label="Anomaly", s=3, zorder=1)
plt.legend()
plt.tight_layout();

# %% [markdown]
# some anomalies are quite clear (very high values)
#
# notice that we also have a time split here (somehwre around 1.4965*1e9 timestamp) => lets only take the first part of the time series

# %%
df.time.diff().sort_values(ascending=False).head()
# Out:
# timestamp
# 1496538120    99540.0
# 1495018920    12120.0
# 1496052000    10860.0
# 1496034000     7260.0
# 1500038160     7080.0
# Name: time, dtype: float64

# %%
df = df.query("timestamp < 1496538120").copy()
df["time"] = df.index - df.index[0]
df["vd"] = df["value"].diff()

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))

plt.plot(df.value, alpha=0.5)
t = df.query("label==1")
plt.scatter(t.index, t.value, color="red", alpha=0.8, label="Anomaly", s=3, zorder=1)
plt.legend()
plt.tight_layout();

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))

plt.plot(df.vd, alpha=0.5)
t = df.query("label==1")
plt.scatter(t.index, t.vd, color="red", alpha=0.8, label="Anomaly", s=3, zorder=1)
plt.legend()
plt.tight_layout();

# %% [markdown]
# looks nice! (althought the anomalies are grouped together, might be bad for evaluation...)

# %%
df.label.value_counts(normalize=True)
# Out:
# label
# 0    0.958799
# 1    0.041201
# Name: proportion, dtype: float64

# %% [markdown]
# lets also split it into train and test

# %%
split_idx = 1.495 * 1e9
tr = df[df.index < split_idx].copy()
te = df[df.index >= split_idx].copy()

# %%
tr.label.value_counts(normalize=True), te.label.value_counts(normalize=True)
# Out:
# (label
#  0    0.96727
#  1    0.03273
#  Name: proportion, dtype: float64,
#  label
#  0    0.950141
#  1    0.049859
#  Name: proportion, dtype: float64)

# %%
len(tr), len(te)
# Out:
# (23495, 22985)

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))

plt.plot(df.vd, alpha=0.5)
plt.axvline(split_idx, color="g", label="split")
t = df.query("label==1")
plt.scatter(t.index, t.vd, color="red", alpha=0.8, label="Anomaly", s=3, zorder=1)
plt.legend()
plt.tight_layout();

# %% [markdown]
# ## Baseline solution

# %% [markdown]
# Here I compare the performance (accuracy, latency and thoughput) of a CPU/GPU and FPGA implementation
#
# I will use a simple **Bollinger bands** on value diffs for now

# %%
import sys

print(sys.version)
print(sys.executable)
# Out:
# 3.10.20 (main, Mar 11 2026, 17:46:40) [GCC 14.3.0]
# /home/cym/anaconda3/envs/icl/bin/python

# %%
#https://stackoverflow.com/a/71505610
#https://stackoverflow.com/a/25823885
from timeit import default_timer as timer

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    f1_score,
    precision_score,
    recall_score,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 5
#       1 #https://stackoverflow.com/a/71505610
#       2 #https://stackoverflow.com/a/25823885
#       3 from timeit import default_timer as timer
# ----> 5 from sklearn.metrics import (
#       6     accuracy_score,
#       7     classification_report,
#       8     f1_score,
#       9     precision_score,
#      10     recall_score,
#      11 )
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ## Bollinger bands

# %%
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    # Print the evaluation metrics
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1-score:", f1)

# %%
X_tr = tr.vd.values
X_te = te.vd.values
y_tr = tr.label.values
y_te = te.label.values

# %% [markdown]
# #### CPU

# %% [markdown]
# training: lets optimize f1 score on the train dataset

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 import torch
#       2 print(torch.__version__)
#       3 print(torch.cuda.is_available())
#
# ModuleNotFoundError: No module named 'torch'

# %%
import torch
print(torch.__version__)
# Out:
# 1.13.1+cu116

# %%
from src.BB import BB
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.BB import BB
#
# ModuleNotFoundError: No module named 'src'

# %% [markdown]
# > accuracy

# %%
window_size = 20
bb = BB(init_obs=X_tr[-window_size:], window_size=window_size, num_std=2)
y_pr = bb.predict_many(X_te)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 window_size = 20
# ----> 2 bb = BB(init_obs=X_tr[-window_size:], window_size=window_size, num_std=2)
#       3 y_pr = bb.predict_many(X_te)
#
# NameError: name 'BB' is not defined

# %%
evaluate_model(y_te, y_pr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 evaluate_model(y_te, y_pr)
#
# NameError: name 'y_pr' is not defined

# %% [markdown]
# very low precision/recall, as expected

# %%
te["pred"] = y_pr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 te["pred"] = y_pr
#
# NameError: name 'y_pr' is not defined

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))

plt.plot(te.vd, alpha=0.5)
t = te.query("label==1 & pred==1")
plt.scatter(t.index, t.vd, color="red", alpha=0.8, label="Correctly predicted", s=3, zorder=1)
plt.legend()
plt.tight_layout();
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File ~/anaconda3/envs/icl/lib/python3.10/collections/__init__.py:986, in ChainMap.__getitem__(self, key)
#     985         pass
# --> 986 return self.__missing__(key)
#
# File ~/anaconda3/envs/icl/lib/python3.10/collections/__init__.py:978, in ChainMap.__missing__(self, key)
#     977 def __missing__(self, key):
# --> 978     raise KeyError(key)
#
# KeyError: 'pred'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'pred'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[37], line 4
#       1 fig, axs = plt.subplots(1, 1, figsize=(8, 6))
#       3 plt.plot(te.vd, alpha=0.5)
# ----> 4 t = te.query("label==1 & pred==1")
#       5 plt.scatter(t.index, t.vd, color="red", alpha=0.8, label="Correctly predicted", s=3, zorder=1)
#       6 plt.legend()
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/frame.py:4834, in DataFrame.query(self, expr, inplace, **kwargs)
#    4832 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4833 kwargs["target"] = None
# -> 4834 res = self.eval(expr, **kwargs)
#    4836 try:
#    4837     result = self.loc[res]
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/frame.py:4960, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4957     kwargs["target"] = self
#    4958 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4960 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/eval.py:339, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     330 # get our (possibly passed-in) scope
#     331 env = ensure_scope(
#     332     level + 1,
#     333     global_dict=global_dict,
#    (...)
#     336     target=target,
#     337 )
# --> 339 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     341 if engine == "numexpr" and (
#     342     (
#     343         is_extension_array_dtype(parsed_expr.terms.return_type)
#    (...)
#     350     )
#     351 ):
#     352     warnings.warn(
#     353         "Engine has switched to 'python' because numexpr does not support "
#     354         "extension array dtypes. Please set your engine to python manually.",
#     355         RuntimeWarning,
#     356         stacklevel=find_stack_level(),
#     357     )
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:419, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     417     raise SyntaxError("only a single expression is allowed")
#     418 expr = node.body[0]
# --> 419 return self.visit(expr, **kwargs)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:422, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     421 def visit_Expr(self, node, **kwargs):
# --> 422     return self.visit(node.value, **kwargs)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:746, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     745 operands = node.values
# --> 746 return reduce(visitor, operands)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:740, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     738 def visitor(x, y):
#     739     lhs = self._try_visit_binop(x)
# --> 740     rhs = self._try_visit_binop(y)
#     742     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:735, in BaseExprVisitor._try_visit_binop(self, bop)
#     733 if isinstance(bop, (Op, Term)):
#     734     return bop
# --> 735 return self.visit(bop)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:535, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     534 def visit_BinOp(self, node, **kwargs):
# --> 535     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     536     left, right = self._maybe_downcast_constants(left, right)
#     537     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:453, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     451 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     452     if left is None:
# --> 453         left = self.visit(node.left, side="left")
#     454     if right is None:
#     455         right = self.visit(node.right, side="right")
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/expr.py:545, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     544 def visit_Name(self, node, **kwargs) -> Term:
# --> 545     return self.term_type(node.id, self.env, **kwargs)
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and res.ndim > 2:
#
# File ~/anaconda3/envs/icl/lib/python3.10/site-packages/pandas/core/computation/scope.py:244, in Scope.resolve(self, key, is_local)
#     242     return self.temps[key]
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'pred' is not defined

# %% [markdown]
# > latency and throughput without vectorisation

# %%
bb = BB(init_obs=X_tr[-window_size:], window_size=window_size, num_std=2)

# latency
rs = []
times = []
for x in X_te:
    start = timer()
    y = bb.predict_one(x)
    end = timer()
    bb.update_state(x)
    rs.append(y)
    times.append(end - start)
rs = np.array(rs)
times = pd.Series(times)  # in seconds
times *= 1e6  # in microseconds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 bb = BB(init_obs=X_tr[-window_size:], window_size=window_size, num_std=2)
#       3 # latency
#       4 rs = []
#
# NameError: name 'BB' is not defined

# %%
fig, axs = plt.subplots(1, 1, figsize=(4, 4))
plt.hist(times, bins=60)
plt.yscale("log")
plt.title("Latency distribution")
plt.xlabel("Time (microsecond)");

# %% [markdown]
# > without the outlier

# %%
fig, axs = plt.subplots(1, 1, figsize=(4, 4))
plt.hist(times[times < 200], bins=60)
plt.yscale("log")
plt.title("Latency distribution")
plt.xlabel("Time (microsecond)");

# %%
times.quantile([0.1, 0.5, 0.75, 0.9, 0.95, 0.99])
# Out:
# 0.10    0.978998
# 0.50    1.034998
# 0.75    1.072000
# 0.90    1.121000
# 0.95    1.179000
# 0.99    3.183122
# dtype: float64

# %%
times.mean()
# Out:
# 1.137111037604161

# %% [markdown]
# mean latency is 1 microsecond

# %%
# throughput without vectorisation
throughput_not_vec = len(X_te) / sum(times / 1e6)
print(f"Throughput (not vectorised): {throughput_not_vec} samples/second")
# Out:
# Throughput (not vectorised): 879421.5929052562 samples/second

# %% [markdown]
# > throughput vectorised

# %%
# throughput
N_RUNS = 20
times = []
for _ in range(N_RUNS):
    bb = BB(init_obs=X_tr[-window_size:], window_size=window_size, num_std=2)
    start = timer()
    y_pr = bb.predict_many(X_te)
    end = timer()
    times.append(end - start)
times = pd.Series(times)  # in seconds
times *= 1e6  # in microseconds

# %%
throughputs = len(X_te) / (times / 1e6)

# %%
fig, axs = plt.subplots(1, 1, figsize=(4, 4))
plt.hist(throughputs, bins=60)
plt.yscale("log")
plt.title("Throughput distribution")
plt.xlabel("Throughput (samples/second)");

# %%
# throughput with vectorisation
throughput_not_vec = throughputs.mean()
print(f"Throughput (vectorised): {throughput_not_vec} samples/second")
# Out:
# Throughput (vectorised): 62208538.87569586 samples/second

# %% [markdown]
# good improvement over not vectorised version

# %% [markdown]
# ### GPU

# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print(torch.cuda.is_available(), device)
torch.cuda.empty_cache()
# Out:
# True cuda

# %%
import bottleneck as bn

from src.BB import BB_gpu, moving_mean_std

# %%
X_tr = tr.vd.values
X_te = te.vd.values
y_tr = tr.label.values
y_te = te.label.values

X_tr = torch.tensor(X_tr).to(device)
X_te = torch.tensor(X_te).to(device)

# y_tr = torch.tensor(y_tr).to(device)
# y_te = torch.tensor(y_te).to(device)

# %% [markdown]
# > accuracy

# %%
window_size = 20
bb = BB_gpu(init_obs=X_tr[-window_size:], window_size=window_size, num_std=2)
y_pr = bb.predict_many(X_te)
y_pr = y_pr.to("cpu")

# %%
evaluate_model(y_te, y_pr)
# Out:
# Accuracy: 0.9075048944964107
# Precision: 0.1016260162601626
# Recall: 0.10907504363001745
# F1-score: 0.10521885521885521

# %% [markdown]
# very low precision/recall, as expected

# %%
te["pred"] = y_pr

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))

plt.plot(te.vd, alpha=0.5)
t = te.query("label==1 & pred==1")
plt.scatter(t.index, t.vd, color="red", alpha=0.8, label="Correctly predicted", s=3, zorder=1)
plt.legend()
plt.tight_layout();

# %% [markdown]
# same predictions as CPU version

# %% [markdown]
# > latency and throughput without vectorisation

# %%
bb = BB_gpu(init_obs=X_tr[-window_size:], window_size=window_size, num_std=2)

# latency
rs = []
times = []
for x in X_te:
    start = timer()
    y = bb.predict_one(x)
    end = timer()
    bb.update_state(x)
    rs.append(y)
    times.append(end - start)
rs = np.array(rs)
times = pd.Series(times)  # in seconds
times *= 1e6  # in microseconds

# %%
fig, axs = plt.subplots(1, 1, figsize=(4, 4))
plt.hist(times, bins=60)
plt.yscale("log")
plt.title("Latency distribution")
plt.xlabel("Time (microsecond)");

# %%
times.quantile([0.1, 0.5, 0.75, 0.9, 0.95, 0.99])
# Out:
# 0.10     85.854399
# 0.50     86.839002
# 0.75     87.685999
# 0.90     91.115398
# 0.95     98.366000
# 0.99    156.234000
# dtype: float64

# %%
# throughput without vectorisation
throughput_not_vec = len(X_te) / sum(times / 1e6)
print(f"Throughput (not vectorised): {throughput_not_vec} samples/second")
# Out:
# Throughput (not vectorised): 10949.416168447493 samples/second

# %% [markdown]
# much slower than the cpu version (which is expected since we are moving the data around too much)

# %% [markdown]
# > throughput vectorised

# %%
# throughput
N_RUNS = 20
times = []
for _ in range(N_RUNS):
    bb = BB_gpu(init_obs=X_tr[-window_size:], window_size=window_size, num_std=2)
    start = timer()
    y_pr = bb.predict_many(X_te)
    end = timer()
    times.append(end - start)
times = pd.Series(times)  # in seconds
times *= 1e6  # in microseconds

# %%
throughputs = len(X_te) / (times / 1e6)

# %%
fig, axs = plt.subplots(1, 1, figsize=(4, 4))
plt.hist(throughputs, bins=60)
plt.yscale("log")
plt.title("Throughput distribution")
plt.xlabel("Throughput (samples/second)");

# %%
# throughput with vectorisation
throughput_not_vec = throughputs.mean()
print(f"Throughput (vectorised): {throughput_not_vec} samples/second")
# Out:
# Throughput (vectorised): 44728721.87220856 samples/second

# %% [markdown]
# smaller than the cpu version
#
# that is expected, we cannot benefit a lot from a gpu for bollinger bands

# %% [markdown]
# ### FPGA

# %% [markdown]
# TODO

# %% [markdown]
# ## Transformer

# %% [markdown]
# Here I use a simple multihead attention layer to do the inference

# %% [markdown]
# the input features are simple the lags of the time series

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

from src.transformer import MultiheadAttention


class Transformer(nn.Module):
    def __init__(self, input_dim, embed_dim, num_heads, output_dim=1):
        super().__init__()
        self.attn = MultiheadAttention(input_dim=input_dim, embed_dim=embed_dim, num_heads=num_heads)
        self.out = nn.Sequential(nn.Linear(embed_dim, output_dim), nn.Sigmoid())

    def forward(self, x):
        x = self.attn(x)
        return self.out(x).squeeze(-1)

# %%
t = df.copy()
for lag in range(1, 10):
    t[f"lag_vd_{lag}"] = t["vd"].shift(lag)
    t[f"lag_label_{lag}"] = t["label"].shift(lag)
t = t.dropna()
tr_cols = [c for c in t.columns if "lag" in c] + ["vd"]

# %%
split_idx = 1.495 * 1e9
tr = t[t.index < split_idx].copy()
te = t[t.index >= split_idx].copy()

# %%
x = tr[tr_cols].values
x = torch.tensor(x, dtype=torch.float32)
y = torch.tensor(tr.label.values, dtype=torch.float32)
print(x.shape, y.shape)
# Out:
# torch.Size([23485, 19]) torch.Size([23485])

# %%
loader = DataLoader(list(zip(x, y)), shuffle=False, batch_size=16)

# %%
input_dim = len(tr_cols)
embed_dim = 20
num_heads = 4

model = Transformer(input_dim, embed_dim, num_heads, output_dim=1)

# %%
n_epochs = 10
loss_fn = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Debug-only shape check removed: y_batch/y_pred are defined inside the training loop.

# %%
losses = []
f1s = []
for epoch in range(n_epochs):
    epoch_losses = []
    all_y_true = []
    all_y_preds = []
    print(f"{epoch=}")
    for X_batch, y_batch in loader:
        X_batch = X_batch.unsqueeze(0)
        y_batch = y_batch.unsqueeze(0)
        # so x shape is (batch_size, sequence length, features)

        # forward pass
        y_pred = model(X_batch)
        loss = loss_fn(y_pred, y_batch)

        # backward pass
        optimizer.zero_grad()
        loss.backward()
        # update weights
        optimizer.step()

        epoch_losses.append(loss.detach().numpy())
        all_y_true.append(y_batch.detach().numpy())
        all_y_preds.append(y_pred.detach().numpy())

    all_y_true = np.hstack(all_y_true).astype(int).ravel()
    all_y_preds = np.hstack(all_y_preds).astype(int).ravel()

    epoch_losses = np.array(epoch_losses)
    epoch_losses = epoch_losses.mean()
    losses.append(epoch_losses)

    f1 = f1_score(all_y_true, all_y_preds)
    f1s.append(f1)

losses = np.array(losses)
# Out:
# epoch=0
# epoch=1
# epoch=2
# epoch=3
# epoch=4
# epoch=5
# epoch=6
# epoch=7
# epoch=8
# epoch=9

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
plt.sca(axs[0])
plt.plot(losses)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.sca(axs[1])
plt.plot(f1s)
plt.xlabel("Epoch")
plt.xlabel("F1")
plt.tight_layout();

# %% [markdown]
# a large improvement in terms of F1 score!

# %%
PATH = "../data/models/transformer_baseline"

# %%
# https://stackoverflow.com/a/49078976
torch.save(model.state_dict(), PATH)

# %% [markdown]
# ### inference

# %%
model = Transformer(input_dim, embed_dim, num_heads, output_dim=1)
model.load_state_dict(torch.load(PATH))
model.eval();

# %% [markdown]
# > accuracy

# %%
x = te[tr_cols].values
x = torch.tensor(x, dtype=torch.float32)
y = torch.tensor(te.label.values, dtype=torch.float32)
print(x.shape, y.shape)
# Out:
# torch.Size([22985, 19]) torch.Size([22985])

# %%
loader = DataLoader(list(zip(x, y)), shuffle=False, batch_size=16)

# %%
all_y_true = []
all_y_preds = []
for X_batch, y_batch in loader:
    X_batch = X_batch.unsqueeze(0)
    y_batch = y_batch.unsqueeze(0)
    # so x shape is (batch_size, sequence length, features)

    # forward pass
    y_pred = model(X_batch)

    all_y_true.append(y_batch.detach().numpy())
    all_y_preds.append(y_pred.detach().numpy())

all_y_true = np.hstack(all_y_true).astype(int).ravel()
all_y_preds = np.hstack(all_y_preds).astype(int).ravel()

# %%
evaluate_model(all_y_true, all_y_preds)
# Out:
# Accuracy: 0.9624972808353274
# Precision: 1.0
# Recall: 0.24781849912739964
# F1-score: 0.39720279720279716

# %% [markdown]
# much bigger F1-Score on test

# %%
te["pred"] = all_y_preds

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))

plt.plot(te.vd, alpha=0.5)
t = te.query("label==1 & pred==1")
plt.scatter(t.index, t.vd, color="red", alpha=0.8, label="Correctly predicted", s=3, zorder=1)
plt.legend()
plt.tight_layout();

# %% [markdown]
# > speed on CPU

# %%
times = []

all_y_true = []
all_y_preds = []
for X_batch, y_batch in loader:
    X_batch = X_batch.unsqueeze(0)
    y_batch = y_batch.unsqueeze(0)
    # so x shape is (batch_size, sequence length, features)

    start = timer()
    y_pred = model(X_batch)
    end = timer()

    times.extend([(end - start)] * X_batch.size(1))

    all_y_true.append(y_batch.detach().numpy())
    all_y_preds.append(y_pred.detach().numpy())

all_y_true = np.hstack(all_y_true).astype(int).ravel()
all_y_preds = np.hstack(all_y_preds).astype(int).ravel()
times = pd.Series(times)
times *= 1e6

# %%
fig, axs = plt.subplots(1, 1, figsize=(4, 4))
plt.hist(times, bins=60)
plt.yscale("log")
plt.title("Latency distribution")
plt.xlabel("Time (microsecond)");

# %%
times.quantile([0.1, 0.5, 0.75, 0.9, 0.95, 0.99])
# Out:
# 0.10     439.904004
# 0.50     449.112995
# 0.75     514.346997
# 0.90     738.791998
# 0.95     849.453005
# 0.99    1145.406997
# dtype: float64

# %%
times.mean()
# Out:
# 526.0562745998277

# %% [markdown]
# slower than bollinger bands...

# %%
# throughput without vectorisation
throughput_not_vec = len(X_te) / sum(times / 1e6)
print(f"Throughput (not vectorised): {throughput_not_vec} samples/second")
# Out:
# Throughput (not vectorised): 1900.9373108622312 samples/second

# %% [markdown]
# ### torch.compile

# %% [markdown]
# a new feature in torch 2.0: https://pytorch.org/get-started/pytorch-2.0/#pytorch-2x-faster-more-pythonic-and-as-dynamic-as-ever

# %%
# torch.compile can be slow or unavailable in some CPU-only notebook environments.
try:
    torch._dynamo.reset()
    compiled_model = torch.compile(model, mode="max-autotune")
except Exception as exc:
    print(f"torch.compile unavailable, using eager model: {exc}")
    compiled_model = model
compiled_model.eval();

# %%
compiled_model(X_batch);

# %%
times = []

all_y_true = []
all_y_preds = []
for X_batch, y_batch in loader:
    X_batch = X_batch.unsqueeze(0)
    y_batch = y_batch.unsqueeze(0)
    # so x shape is (batch_size, sequence length, features)

    start = timer()
    # USING COMPILED MODEL
    y_pred = compiled_model(X_batch)
    end = timer()

    times.extend([(end - start)] * X_batch.size(1))

    all_y_true.append(y_batch.detach().numpy())
    all_y_preds.append(y_pred.detach().numpy())

all_y_true = np.hstack(all_y_true).astype(int).ravel()
all_y_preds = np.hstack(all_y_preds).astype(int).ravel()
times = pd.Series(times)
times *= 1e6

# %%
fig, axs = plt.subplots(1, 1, figsize=(4, 4))
plt.hist(times, bins=60)
plt.yscale("log")
plt.title("Latency distribution")
plt.xlabel("Time (microsecond)");

# %%
fig, axs = plt.subplots(1, 1, figsize=(4, 4))
plt.hist(times[times < 200000], bins=60)
plt.yscale("log")
plt.title("Latency distribution")
plt.xlabel("Time (microsecond)");

# %%
times.quantile([0.1, 0.5, 0.75, 0.9, 0.95, 0.99])
# Out:
# 0.10    493.295003
# 0.50    500.948001
# 0.75    520.363996
# 0.90    606.501999
# 0.95    799.861999
# 0.99    926.183995
# dtype: float64

# %%
times.mean()
# Out:
# 1115.7382657097924

# %% [markdown]
# latency distribution looks better, but still have a large outlier...

# %%
# throughput without vectorisation
throughput_not_vec = len(X_te) / sum(times / 1e6)
print(f"Throughput (not vectorised): {throughput_not_vec} samples/second")
# Out:
# Throughput (not vectorised): 896.2675483428329 samples/second
